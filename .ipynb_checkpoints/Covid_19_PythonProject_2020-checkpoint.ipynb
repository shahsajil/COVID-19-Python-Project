# %%
# importing libraries needed for this Project
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ploty.express as px
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-60-5d36be5d77bf> in <module>
#       4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
# ----> 6 import ploty.express as px
#
# ModuleNotFoundError: No module named 'ploty'

# %%
# importing excel dataset into notebook
df = pd.read_excel ('Covid_19.xlsx')

# %%
# displaying the dataset 
df
# Out:
#              Country, Other  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0                     China        80894        NaN        3237.0         NaN
# 1                     Italy        35713     4207.0        2978.0       475.0
# 2                      Iran        17361     1192.0        1135.0       147.0
# 3                     Spain        14769     2943.0         638.0       105.0
# 4                   Germany        12327     2960.0          28.0         2.0
# 5                       USA         9235     2824.0         150.0        41.0
# 6                    France         9134     1404.0         264.0        89.0
# 7                  S. Korea         8413       93.0          84.0         3.0
# 8               Switzerland         3115      373.0          33.0         6.0
# 9                        UK         2626      676.0         104.0        33.0
# 10              Netherlands         2051      346.0          58.0        15.0
# ...

# %%
# data cleaning replacing the NaN with 0 value
df = df.fillna(0)

# %%
# displaying dataset after data cleaning 
df
# Out:
#              Country, Other  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0                     China        80894        0.0        3237.0         0.0
# 1                     Italy        35713     4207.0        2978.0       475.0
# 2                      Iran        17361     1192.0        1135.0       147.0
# 3                     Spain        14769     2943.0         638.0       105.0
# 4                   Germany        12327     2960.0          28.0         2.0
# 5                       USA         9235     2824.0         150.0        41.0
# 6                    France         9134     1404.0         264.0        89.0
# 7                  S. Korea         8413       93.0          84.0         3.0
# 8               Switzerland         3115      373.0          33.0         6.0
# 9                        UK         2626      676.0         104.0        33.0
# 10              Netherlands         2051      346.0          58.0        15.0
# ...

# %%
# Adding columns (Total Cases and New Cases) and (Total Deaths and New Deaths)
df["Total Cases (Up To Date)"] = df["Total Cases"]+df["New Cases"]
df["Total Deaths (Up To Date)"] = df["Total Deaths"]+df["New Deaths"]

# %%
# displaying dataset with new columns
df
# Out:
#              Country, Other  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0                     China        80894        0.0        3237.0         0.0
# 1                     Italy        35713     4207.0        2978.0       475.0
# 2                      Iran        17361     1192.0        1135.0       147.0
# 3                     Spain        14769     2943.0         638.0       105.0
# 4                   Germany        12327     2960.0          28.0         2.0
# 5                       USA         9235     2824.0         150.0        41.0
# 6                    France         9134     1404.0         264.0        89.0
# 7                  S. Korea         8413       93.0          84.0         3.0
# 8               Switzerland         3115      373.0          33.0         6.0
# 9                        UK         2626      676.0         104.0        33.0
# 10              Netherlands         2051      346.0          58.0        15.0
# ...

# %%
# diplaying the needed columns only 
totalcases_df = df[["Country, Other", "Total Cases (Up To Date)"]]

# %%
totalcases_df.sort_values("Total Cases (Up To Date)", ascending=False)
# Out:
#              Country, Other  Total Cases (Up To Date)
# 174                  Total:                  238877.0
# 0                     China                   80894.0
# 1                     Italy                   39920.0
# 2                      Iran                   18553.0
# 3                     Spain                   17712.0
# 4                   Germany                   15287.0
# 5                       USA                   12059.0
# 6                    France                   10538.0
# 7                  S. Korea                    8506.0
# 8               Switzerland                    3488.0
# 9                        UK                    3302.0
# 10              Netherlands                    2397.0
# 11                  Austria                    1960.0
# 13                  Belgium                    1729.0
# 12                   Norway                    1707.0
# 14                   Sweden                    1388.0
# ...

# %%
totalcases_df[['Country, Other', 'Total Cases (Up To Date)']].set_index ('Country, Other')[:25].plot.bar()

# %%
# diplaying the needed columns only 
totaldeaths_df = df[["Country, Other", "Total Deaths (Up To Date)"]]

# %%
totaldeaths_df.sort_values("Total Deaths (Up To Date)", ascending=False)
# Out:
#              Country, Other  Total Deaths (Up To Date)
# 174                  Total:                     9898.0
# 1                     Italy                     3453.0
# 0                     China                     3237.0
# 2                      Iran                     1282.0
# 3                     Spain                      743.0
# 6                    France                      353.0
# 5                       USA                      191.0
# 9                        UK                      137.0
# 7                  S. Korea                       87.0
# 10              Netherlands                       73.0
# 8               Switzerland                       39.0
# 39                Indonesia                       31.0
# 4                   Germany                       30.0
# 16                    Japan                       29.0
# 43              Philippines                       20.0
# 13                  Belgium                       18.0
# ...

# %%
totaldeaths_df[['Country, Other', 'Total Deaths (Up To Date)']].set_index ('Country, Other')[:10].plot.bar()

# %%
sns.barplot(data=totaldeaths_df[:10],x='Country, Other', y='Total Deaths (Up To Date)')

# %%
plot.bar(dataframe=df[:10]), x='Country, Other', y='Total Deaths(Up to Date)', color='Total Cases (Up To Date)')
# Out:
#   File "<ipython-input-72-046e70198cbe>", line 1
#     plot.bar(dataframe=df[:10]), x='Country, Other', y='Total Deaths(Up to Date)', color='Total Cases (Up To Date)')
#                                                                                                                    ^
# SyntaxError: invalid syntax
